# %%
import requests

API_KEY = "84fc0155e583f3f7dbb0cafbea8ad4ed"
TMDB_API_URL = "https://api.themoviedb.org/3"

def fetch_movie_details(tmdb_id):
    url = f"{TMDB_API_URL}/movie/{tmdb_id}?api_key={API_KEY}"
    response = requests.get(url)
    if response.status_code == 200:
        return response.json()
    return None

def fetch_movie_credits(tmdb_id):
    url = f"{TMDB_API_URL}/movie/{tmdb_id}/credits?api_key={API_KEY}"
    response = requests.get(url)
    if response.status_code == 200:
        return response.json()
    return None

# %%
import pandas as pd

# Load the CSV files
links = pd.read_csv("ml-32m/links.csv")
movies = pd.read_csv("ml-32m/movies.csv")
ratings = pd.read_csv("ml-32m/ratings.csv")
tags = pd.read_csv("ml-32m/tags.csv")

# Preview the data
print(movies.head())
print(links.head())
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
movie_rating_counts = ratings['movieId'].value_counts()
top_movie_ids = movie_rating_counts.head(int(len(movie_rating_counts) * 0.10)).index

# Filter ratings to only include the top movies
filtered_ratings = ratings[ratings['movieId'].isin(top_movie_ids)]

# Save the filtered ratings
filtered_ratings.to_csv('filtered_ratings_top_movies.csv', index=False)

print(f"Filtered ratings to include top {len(top_movie_ids)} impactful movies.")
# Out:
# Filtered ratings to include top 8443 impactful movies.

# %%
user_rating_counts = filtered_ratings['userId'].value_counts()

# Select the top users
top_user_ids = user_rating_counts.head(500).index  # Adjust the number as needed

# Further filter ratings to include only the top users
final_filtered_ratings = filtered_ratings[filtered_ratings['userId'].isin(top_user_ids)]

# Save the final filtered ratings
final_filtered_ratings.to_csv('final_filtered_ratings.csv', index=False)

print(f"Filtered ratings to include top {len(top_user_ids)} active users.")
# Out:
# Filtered ratings to include top 500 active users.

# %%
# Filter tags for relevant movies and users
filtered_tags = tags[
    tags['movieId'].isin(final_filtered_ratings['movieId']) & 
    tags['userId'].isin(final_filtered_ratings['userId'])
]

# Save the filtered tags
filtered_tags.to_csv('final_filtered_tags.csv', index=False)

print("Filtered tags for relevant movies and users.")
# Out:
# Filtered tags for relevant movies and users.

# %%
impactful_movies = movies[movies['movieId'].isin(top_movie_ids)]

# Save filtered movies
impactful_movies.to_csv('impactful_movies.csv', index=False)

print(f"Identified {len(impactful_movies)} impactful movies.")
# Out:
# Identified 8443 impactful movies.

# %%
#Merging data if and only if the data has been linked to tmdb

movie_data = impactful_movies.merge(links, on="movieId", how="inner")
print(len(movie_data))
# Out:
# 8443

# %%
movie_data = movie_data[movie_data['tmdbId'].notnull()]
movie_data['tmdbId'] = movie_data['tmdbId'].astype(int)

# %%
#enriching the data

import time

enriched_data = []

for _, row in movie_data.iterrows():
    tmdb_id = row['tmdbId']
    details = fetch_movie_details(tmdb_id)
    credits = fetch_movie_credits(tmdb_id)
    
    if details and credits:
        director = [person['name'] for person in credits['crew'] if person['job'] == 'Director']
        actors = [person['name'] for person in credits['cast'][:5]]  # Top 5 actors
        enriched_data.append({
            "movieId": row['movieId'],
            "title": row['title'],
            "genres": row['genres'],
            "tmdbId": tmdb_id,
            "director": director,
            "actors": actors,
            "tmdb_genres": [genre['name'] for genre in details['genres']],
            "release_date": details['release_date'],
            "runtime": details['runtime']
        })

    # Respect TMDb API rate limits
    time.sleep(0.2)  # Adjust if necessary

# Save the enriched data
enriched_df = pd.DataFrame(enriched_data)
enriched_df.to_csv("enriched_impactful_movies.csv", index=False)
print(enriched_df.head())
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  tmdbId           director  \
# 0  Adventure|Animation|Children|Comedy|Fantasy     862    [John Lasseter]
# 1                   Adventure|Children|Fantasy    8844     [Joe Johnston]
# 2                               Comedy|Romance   15602    [Howard Deutch]
# 3                         Comedy|Drama|Romance   31357  [Forest Whitaker]
# 4                                       Comedy   11862    [Charles Shyer]
#
#                                               actors  \
# 0  [Tom Hanks, Tim Allen, Don Rickles, Jim Varney...
# 1  [Robin Williams, Kirsten Dunst, Bradley Pierce...
# 2  [Walter Matthau, Jack Lemmon, Ann-Margret, Sop...
# 3  [Whitney Houston, Angela Bassett, Loretta Devi...
# 4  [Steve Martin, Diane Keaton, Martin Short, Kim...
#
#                               tmdb_genres release_date  runtime
# 0  [Animation, Adventure, Family, Comedy]   1995-10-30       81
# 1            [Adventure, Fantasy, Family]   1995-12-15      104
# 2                       [Romance, Comedy]   1995-12-22      101
# 3                [Comedy, Drama, Romance]   1995-12-22      127
# 4                        [Comedy, Family]   1995-12-08      106

# %%
len(enriched_data)
# Out:
# 8389

# %%
from arango import ArangoClient
import pandas as pd

# Step 1: Connect to ArangoDB
client = ArangoClient()
db = client.db('movieRecommendations', username='root', password='rootPassword')

# Step 2: Read the enriched data from CSV
csv_file = "enriched_impactful_movies.csv"  # Path to your CSV file
movies_df = pd.read_csv(csv_file)

# Step 3: Access or Create the Movies Collection
if not db.has_collection('movies'):
    movies_collection = db.create_collection('movies')
else:
    movies_collection = db.collection('movies')

# Step 4: Load Data into the Collection
for _, row in movies_df.iterrows():
    document = {
        "_key": str(row['movieId']),  # Use movieId as the document key
        "title": row['title'],
        "genres": row['genres'].split('|'),  # Split genres into a list
        "director": row['director'].strip("[]").replace("'", "").split(', '),  # Convert string to list
        "actors": row['actors'].strip("[]").replace("'", "").split(', '),  # Convert string to list
        "tmdb_genres": row['tmdb_genres'].strip("[]").replace("'", "").split(', '),  # Convert string to list
        "release_date": row['release_date'],
        "runtime": row['runtime']
    }
    
    # Insert document into the collection
    try:
        movies_collection.insert(document)
    except Exception as e:
        print(f"Error inserting document {row['movieId']}: {e}")

print("Data loading completed.")
# Out:
# Data loading completed.

# %%
enriched_movies = pd.read_csv('enriched_movies_updated.csv')
valid_movie_ids = set(enriched_movies['movieId'])  # Get valid movie IDs

# Load and filter ratings.csv
ratings = pd.read_csv('ml-32m/ratings.csv')
filtered_ratings = ratings[ratings['movieId'].isin(valid_movie_ids)]

# Save the filtered ratings to a new CSV
filtered_ratings.to_csv('filtered_ratings.csv', index=False)

# Load and filter tags.csv
tags = pd.read_csv('ml-32m/tags.csv')
filtered_tags = tags[tags['movieId'].isin(valid_movie_ids)]

# Save the filtered tags to a new CSV
filtered_tags.to_csv('filtered_tags.csv', index=False)

print("Preprocessing completed. Filtered ratings and tags saved.")
# Out:
# Preprocessing completed. Filtered ratings and tags saved.

# %%
if not db.has_collection('ratings'):
    ratings_collection = db.create_collection('ratings')
else:
    ratings_collection = db.collection('ratings')

# Load filtered ratings data into the collection
filtered_ratings = pd.read_csv('final_filtered_ratings.csv')

for _, row in filtered_ratings.iterrows():
    document = {
        "_key": f"{row['userId']}_{row['movieId']}",  # Create a composite key
        "userId": row['userId'],
        "movieId": row['movieId'],
        "rating": row['rating'],
        "timestamp": row['timestamp']
    }
    
    try:
        ratings_collection.insert(document)
    except Exception as e:
        print(f"Error inserting rating document {row['userId']}_{row['movieId']}: {e}")

print("Ratings data loading completed.")
# Out:
# Ratings data loading completed.

# %%
from arango import ArangoClient
import pandas as pd

# Step 1: Connect to ArangoDB
client = ArangoClient()
db = client.db('movieRecommendations', username='root', password='rootPassword')

# %%
ratings = pd.read_csv('filtered_ratings_top_movies.csv')
edges = [
    {
        "_from": f"Users/{row['userId']}",
        "_to": f"Movies/{row['movieId']}",
        "rating": row['rating'],
        "timestamp": row['timestamp']
    }
    for _, row in ratings.iterrows()
]

# Insert edges into the 'Rated' collection

# %%
from arango import ArangoClient
import pandas as pd

# Step 1: Connect to ArangoDB
client = ArangoClient()
db = client.db('movieRecommendations', username='root', password='rootPassword')
rated_collection = db.collection('rated')

# %%
from math import ceil
chunk_size = 1000  # Adjust based on your system's capacity
num_chunks = ceil(len(edges) / chunk_size)

for i in range(num_chunks):
    start = i * chunk_size
    end = start + chunk_size
    chunk = edges[start:end]  # Get a subset of edges

    try:
        rated_collection.import_bulk(chunk)  # Import the chunk
        print(f"Chunk {i + 1}/{num_chunks} imported successfully")
    except Exception as e:
        print(f"Error importing chunk {i + 1}: {e}")
# Out:
# Chunk 1/30626 imported successfully
# Chunk 2/30626 imported successfully
# Chunk 3/30626 imported successfully
# Chunk 4/30626 imported successfully
# Chunk 5/30626 imported successfully
# Chunk 6/30626 imported successfully
# Chunk 7/30626 imported successfully
# Chunk 8/30626 imported successfully
# Chunk 9/30626 imported successfully
# Chunk 10/30626 imported successfully
# Chunk 11/30626 imported successfully
# Chunk 12/30626 imported successfully
# Chunk 13/30626 imported successfully
# Chunk 14/30626 imported successfully
# Chunk 15/30626 imported successfully
# Chunk 16/30626 imported successfully
# Chunk 17/30626 imported successfully
# Chunk 18/30626 imported successfully
# Chunk 19/30626 imported successfully
# Chunk 20/30626 imported successfully
# Chunk 21/30626 imported successfully
# Chunk 22/30626 imported successfully
# Chunk 23/30626 imported successfully
# Chunk 24/30626 imported successfully
# Chunk 25/30626 imported successfully
# Chunk 26/30626 imported successfully
# Chunk 27/30626 imported successfully
# Chunk 28/30626 imported successfully
# Chunk 29/30626 imported successfully
# Chunk 30/30626 imported successfully
# Chunk 31/30626 imported successfully
# Chunk 32/30626 imported successfully
# Chunk 33/30626 imported successfully
# Chunk 34/30626 imported successfully
# Chunk 35/30626 imported successfully
# Chunk 36/30626 imported successfully
# Chunk 37/30626 imported successfully
# Chunk 38/30626 imported successfully
# Chunk 39/30626 imported successfully
# Chunk 40/30626 imported successfully
# Chunk 41/30626 imported successfully
# Chunk 42/30626 imported successfully
# Chunk 43/30626 imported successfully
# Chunk 44/30626 imported successfully
# Chunk 45/30626 imported successfully
# Chunk 46/30626 imported successfully
# Chunk 47/30626 imported successfully
# Chunk 48/30626 imported successfully
# Chunk 49/30626 imported successfully
# Chunk 50/30626 imported successfully
# Chunk 51/30626 imported successfully
# Chunk 52/30626 imported successfully
# Chunk 53/30626 imported successfully
# Chunk 54/30626 imported successfully
# Chunk 55/30626 imported successfully
# Chunk 56/30626 imported successfully
# Chunk 57/30626 imported successfully
# Chunk 58/30626 imported successfully
# Chunk 59/30626 imported successfully
# Chunk 60/30626 imported successfully
# Chunk 61/30626 imported successfully
# Chunk 62/30626 imported successfully
# Chunk 63/30626 imported successfully
# Chunk 64/30626 imported successfully
# Chunk 65/30626 imported successfully
# Chunk 66/30626 imported successfully
# Chunk 67/30626 imported successfully
# Chunk 68/30626 imported successfully
# Chunk 69/30626 imported successfully
# Chunk 70/30626 imported successfully
# Chunk 71/30626 imported successfully
# Chunk 72/30626 imported successfully
# Chunk 73/30626 imported successfully
# Chunk 74/30626 imported successfully
# Chunk 75/30626 imported successfully
# Chunk 76/30626 imported successfully
# Chunk 77/30626 imported successfully
# Chunk 78/30626 imported successfully
# Chunk 79/30626 imported successfully
# Chunk 80/30626 imported successfully
# Chunk 81/30626 imported successfully
# Chunk 82/30626 imported successfully
# Chunk 83/30626 imported successfully
# Chunk 84/30626 imported successfully
# Chunk 85/30626 imported successfully
# Chunk 86/30626 imported successfully
# Chunk 87/30626 imported successfully
# Chunk 88/30626 imported successfully
# Chunk 89/30626 imported successfully
# Chunk 90/30626 imported successfully
# Chunk 91/30626 imported successfully
# Chunk 92/30626 imported successfully
# Chunk 93/30626 imported successfully
# Chunk 94/30626 imported successfully
# Chunk 95/30626 imported successfully
# Chunk 96/30626 imported successfully
# Chunk 97/30626 imported successfully
# Chunk 98/30626 imported successfully
# Chunk 99/30626 imported successfully
# Chunk 100/30626 imported successfully
# Chunk 101/30626 imported successfully
# Chunk 102/30626 imported successfully
# Chunk 103/30626 imported successfully
# Chunk 104/30626 imported successfully
# Chunk 105/30626 imported successfully
# Chunk 106/30626 imported successfully
# Chunk 107/30626 imported successfully
# Chunk 108/30626 imported successfully
# Chunk 109/30626 imported successfully
# Chunk 110/30626 imported successfully
# Chunk 111/30626 imported successfully
# Chunk 112/30626 imported successfully
# Chunk 113/30626 imported successfully
# Chunk 114/30626 imported successfully
# Chunk 115/30626 imported successfully
# Chunk 116/30626 imported successfully
# Chunk 117/30626 imported successfully
# Chunk 118/30626 imported successfully
# Chunk 119/30626 imported successfully
# Chunk 120/30626 imported successfully
# Chunk 121/30626 imported successfully
# Chunk 122/30626 imported successfully
# Chunk 123/30626 imported successfully
# Chunk 124/30626 imported successfully
# Chunk 125/30626 imported successfully
# Chunk 126/30626 imported successfully
# Chunk 127/30626 imported successfully
# Chunk 128/30626 imported successfully
# Chunk 129/30626 imported successfully
# Chunk 130/30626 imported successfully
# Chunk 131/30626 imported successfully
# Chunk 132/30626 imported successfully
# Chunk 133/30626 imported successfully
# Chunk 134/30626 imported successfully
# Chunk 135/30626 imported successfully
# Chunk 136/30626 imported successfully
# Chunk 137/30626 imported successfully
# Chunk 138/30626 imported successfully
# Chunk 139/30626 imported successfully
# Chunk 140/30626 imported successfully
# Chunk 141/30626 imported successfully
# Chunk 142/30626 imported successfully
# Chunk 143/30626 imported successfully
# Chunk 144/30626 imported successfully
# Chunk 145/30626 imported successfully
# Chunk 146/30626 imported successfully
# Chunk 147/30626 imported successfully
# Chunk 148/30626 imported successfully
# Chunk 149/30626 imported successfully
# Chunk 150/30626 imported successfully
# Chunk 151/30626 imported successfully
# Chunk 152/30626 imported successfully
# Chunk 153/30626 imported successfully
# Chunk 154/30626 imported successfully
# Chunk 155/30626 imported successfully
# Chunk 156/30626 imported successfully
# Chunk 157/30626 imported successfully
# Chunk 158/30626 imported successfully
# Chunk 159/30626 imported successfully
# Chunk 160/30626 imported successfully
# Chunk 161/30626 imported successfully
# Chunk 162/30626 imported successfully
# Chunk 163/30626 imported successfully
# Chunk 164/30626 imported successfully
# Chunk 165/30626 imported successfully
# Chunk 166/30626 imported successfully
# Chunk 167/30626 imported successfully
# Chunk 168/30626 imported successfully
# Chunk 169/30626 imported successfully
# Chunk 170/30626 imported successfully
# Chunk 171/30626 imported successfully
# Chunk 172/30626 imported successfully
# Chunk 173/30626 imported successfully
# Chunk 174/30626 imported successfully
# Chunk 175/30626 imported successfully
# Chunk 176/30626 imported successfully
# Chunk 177/30626 imported successfully
# Chunk 178/30626 imported successfully
# Chunk 179/30626 imported successfully
# Chunk 180/30626 imported successfully
# Chunk 181/30626 imported successfully
# Chunk 182/30626 imported successfully
# Chunk 183/30626 imported successfully
# Chunk 184/30626 imported successfully
# Chunk 185/30626 imported successfully
# Chunk 186/30626 imported successfully
# Chunk 187/30626 imported successfully
# Chunk 188/30626 imported successfully
# Chunk 189/30626 imported successfully
# Chunk 190/30626 imported successfully
# Chunk 191/30626 imported successfully
# Chunk 192/30626 imported successfully
# Chunk 193/30626 imported successfully
# Chunk 194/30626 imported successfully
# Chunk 195/30626 imported successfully
# Chunk 196/30626 imported successfully
# Chunk 197/30626 imported successfully
# Chunk 198/30626 imported successfully
# Chunk 199/30626 imported successfully
# Chunk 200/30626 imported successfully
# Chunk 201/30626 imported successfully
# Chunk 202/30626 imported successfully
# Chunk 203/30626 imported successfully
# Chunk 204/30626 imported successfully
# Chunk 205/30626 imported successfully
# Chunk 206/30626 imported successfully
# Chunk 207/30626 imported successfully
# Chunk 208/30626 imported successfully
# Chunk 209/30626 imported successfully
# Chunk 210/30626 imported successfully
# Chunk 211/30626 imported successfully
# Chunk 212/30626 imported successfully
# Chunk 213/30626 imported successfully
# Chunk 214/30626 imported successfully
# Chunk 215/30626 imported successfully
# Chunk 216/30626 imported successfully
# Chunk 217/30626 imported successfully
# Chunk 218/30626 imported successfully
# Chunk 219/30626 imported successfully
# Chunk 220/30626 imported successfully
# Chunk 221/30626 imported successfully
# Chunk 222/30626 imported successfully
# Chunk 223/30626 imported successfully
# Chunk 224/30626 imported successfully
# Chunk 225/30626 imported successfully
# Chunk 226/30626 imported successfully
# Chunk 227/30626 imported successfully
# Chunk 228/30626 imported successfully
# Chunk 229/30626 imported successfully
# Chunk 230/30626 imported successfully
# Chunk 231/30626 imported successfully
# Chunk 232/30626 imported successfully
# Chunk 233/30626 imported successfully
# Chunk 234/30626 imported successfully
# Chunk 235/30626 imported successfully
# Chunk 236/30626 imported successfully
# Chunk 237/30626 imported successfully
# Chunk 238/30626 imported successfully
# Chunk 239/30626 imported successfully
# Chunk 240/30626 imported successfully
# Chunk 241/30626 imported successfully
# Chunk 242/30626 imported successfully
# Chunk 243/30626 imported successfully
# Chunk 244/30626 imported successfully
# Chunk 245/30626 imported successfully
# Chunk 246/30626 imported successfully
# Chunk 247/30626 imported successfully
# Chunk 248/30626 imported successfully
# Chunk 249/30626 imported successfully
# Chunk 250/30626 imported successfully
# Chunk 251/30626 imported successfully
# Chunk 252/30626 imported successfully
# Chunk 253/30626 imported successfully
# Chunk 254/30626 imported successfully
# Chunk 255/30626 imported successfully
# Chunk 256/30626 imported successfully
# Chunk 257/30626 imported successfully
# Chunk 258/30626 imported successfully
# Chunk 259/30626 imported successfully
# Chunk 260/30626 imported successfully
# Chunk 261/30626 imported successfully
# Chunk 262/30626 imported successfully
# Chunk 263/30626 imported successfully
# Chunk 264/30626 imported successfully
# Chunk 265/30626 imported successfully
# Chunk 266/30626 imported successfully
# Chunk 267/30626 imported successfully
# Chunk 268/30626 imported successfully
# Chunk 269/30626 imported successfully
# Chunk 270/30626 imported successfully
# Chunk 271/30626 imported successfully
# Chunk 272/30626 imported successfully
# Chunk 273/30626 imported successfully
# Chunk 274/30626 imported successfully
# Chunk 275/30626 imported successfully
# Chunk 276/30626 imported successfully
# Chunk 277/30626 imported successfully
# Chunk 278/30626 imported successfully
# Chunk 279/30626 imported successfully
# Chunk 280/30626 imported successfully
# Chunk 281/30626 imported successfully
# Chunk 282/30626 imported successfully
# Chunk 283/30626 imported successfully
# Chunk 284/30626 imported successfully
# Chunk 285/30626 imported successfully
# Chunk 286/30626 imported successfully
# Chunk 287/30626 imported successfully
# Chunk 288/30626 imported successfully
# Chunk 289/30626 imported successfully
# Chunk 290/30626 imported successfully
# Chunk 291/30626 imported successfully
# Chunk 292/30626 imported successfully
# Chunk 293/30626 imported successfully
# Chunk 294/30626 imported successfully
# Chunk 295/30626 imported successfully
# Chunk 296/30626 imported successfully
# Chunk 297/30626 imported successfully
# Chunk 298/30626 imported successfully
# Chunk 299/30626 imported successfully
# Chunk 300/30626 imported successfully
# Chunk 301/30626 imported successfully
# Chunk 302/30626 imported successfully
# Chunk 303/30626 imported successfully
# Chunk 304/30626 imported successfully
# Chunk 305/30626 imported successfully
# Chunk 306/30626 imported successfully
# Chunk 307/30626 imported successfully
# Chunk 308/30626 imported successfully
# Chunk 309/30626 imported successfully
# Chunk 310/30626 imported successfully
# Chunk 311/30626 imported successfully
# Chunk 312/30626 imported successfully
# Chunk 313/30626 imported successfully
# Chunk 314/30626 imported successfully
# Chunk 315/30626 imported successfully
# Chunk 316/30626 imported successfully
# Chunk 317/30626 imported successfully
# Chunk 318/30626 imported successfully
# Chunk 319/30626 imported successfully
# Chunk 320/30626 imported successfully
# Chunk 321/30626 imported successfully
# Chunk 322/30626 imported successfully
# Chunk 323/30626 imported successfully
# Chunk 324/30626 imported successfully
# Chunk 325/30626 imported successfully
# Chunk 326/30626 imported successfully
# Chunk 327/30626 imported successfully
# Chunk 328/30626 imported successfully
# Chunk 329/30626 imported successfully
# Chunk 330/30626 imported successfully
# Chunk 331/30626 imported successfully
# Chunk 332/30626 imported successfully
# Chunk 333/30626 imported successfully
# Chunk 334/30626 imported successfully
# Chunk 335/30626 imported successfully
# Chunk 336/30626 imported successfully
# Chunk 337/30626 imported successfully
# Chunk 338/30626 imported successfully
# Chunk 339/30626 imported successfully
# Chunk 340/30626 imported successfully
# Chunk 341/30626 imported successfully
# Chunk 342/30626 imported successfully
# Chunk 343/30626 imported successfully
# Chunk 344/30626 imported successfully
# Chunk 345/30626 imported successfully
# Chunk 346/30626 imported successfully
# Chunk 347/30626 imported successfully
# Chunk 348/30626 imported successfully
# Chunk 349/30626 imported successfully
# Chunk 350/30626 imported successfully
# Chunk 351/30626 imported successfully
# Chunk 352/30626 imported successfully
# Chunk 353/30626 imported successfully
# Chunk 354/30626 imported successfully
# Chunk 355/30626 imported successfully
# Chunk 356/30626 imported successfully
# Chunk 357/30626 imported successfully
# Chunk 358/30626 imported successfully
# Chunk 359/30626 imported successfully
# Chunk 360/30626 imported successfully
# Chunk 361/30626 imported successfully
# Chunk 362/30626 imported successfully
# Chunk 363/30626 imported successfully
# Chunk 364/30626 imported successfully
# Chunk 365/30626 imported successfully
# Chunk 366/30626 imported successfully
# Chunk 367/30626 imported successfully
# Chunk 368/30626 imported successfully
# Chunk 369/30626 imported successfully
# Chunk 370/30626 imported successfully
# Chunk 371/30626 imported successfully
# Chunk 372/30626 imported successfully
# Chunk 373/30626 imported successfully
# Chunk 374/30626 imported successfully
# Chunk 375/30626 imported successfully
# Chunk 376/30626 imported successfully
# Chunk 377/30626 imported successfully
# Chunk 378/30626 imported successfully
# Chunk 379/30626 imported successfully
# Chunk 380/30626 imported successfully
# Chunk 381/30626 imported successfully
# Chunk 382/30626 imported successfully
# Chunk 383/30626 imported successfully
# Chunk 384/30626 imported successfully
# Chunk 385/30626 imported successfully
# Chunk 386/30626 imported successfully
# Chunk 387/30626 imported successfully
# Chunk 388/30626 imported successfully
# Chunk 389/30626 imported successfully
# Chunk 390/30626 imported successfully
# Chunk 391/30626 imported successfully
# Chunk 392/30626 imported successfully
# Chunk 393/30626 imported successfully
# Chunk 394/30626 imported successfully
# Chunk 395/30626 imported successfully
# Chunk 396/30626 imported successfully
# Chunk 397/30626 imported successfully
# Chunk 398/30626 imported successfully
# Chunk 399/30626 imported successfully
# Chunk 400/30626 imported successfully
# Chunk 401/30626 imported successfully
# Chunk 402/30626 imported successfully
# Chunk 403/30626 imported successfully
# Chunk 404/30626 imported successfully
# Chunk 405/30626 imported successfully
# Chunk 406/30626 imported successfully
# Chunk 407/30626 imported successfully
# Chunk 408/30626 imported successfully
# Chunk 409/30626 imported successfully
# Chunk 410/30626 imported successfully
# Chunk 411/30626 imported successfully
# Chunk 412/30626 imported successfully
# Chunk 413/30626 imported successfully
# Chunk 414/30626 imported successfully
# Chunk 415/30626 imported successfully
# Chunk 416/30626 imported successfully
# Chunk 417/30626 imported successfully
# Chunk 418/30626 imported successfully
# Chunk 419/30626 imported successfully
# Chunk 420/30626 imported successfully
# Chunk 421/30626 imported successfully
# Chunk 422/30626 imported successfully
# Chunk 423/30626 imported successfully
# Chunk 424/30626 imported successfully
# Chunk 425/30626 imported successfully
# Chunk 426/30626 imported successfully
# Chunk 427/30626 imported successfully
# Chunk 428/30626 imported successfully
# Chunk 429/30626 imported successfully
# Chunk 430/30626 imported successfully
# Chunk 431/30626 imported successfully
# Chunk 432/30626 imported successfully
# Chunk 433/30626 imported successfully
# Chunk 434/30626 imported successfully
# Chunk 435/30626 imported successfully
# Chunk 436/30626 imported successfully
# Chunk 437/30626 imported successfully
# Chunk 438/30626 imported successfully
# Chunk 439/30626 imported successfully
# Chunk 440/30626 imported successfully
# Chunk 441/30626 imported successfully
# Chunk 442/30626 imported successfully
# Chunk 443/30626 imported successfully
# Chunk 444/30626 imported successfully
# Chunk 445/30626 imported successfully
# Chunk 446/30626 imported successfully
# Chunk 447/30626 imported successfully
# Chunk 448/30626 imported successfully
# Chunk 449/30626 imported successfully
# Chunk 450/30626 imported successfully
# Chunk 451/30626 imported successfully
# Chunk 452/30626 imported successfully
# Chunk 453/30626 imported successfully
# Chunk 454/30626 imported successfully
# Chunk 455/30626 imported successfully
# Chunk 456/30626 imported successfully
# Chunk 457/30626 imported successfully
# Chunk 458/30626 imported successfully
# Chunk 459/30626 imported successfully
# Chunk 460/30626 imported successfully
# Chunk 461/30626 imported successfully
# Chunk 462/30626 imported successfully
# Chunk 463/30626 imported successfully
# Chunk 464/30626 imported successfully
# Chunk 465/30626 imported successfully
# Chunk 466/30626 imported successfully
# Chunk 467/30626 imported successfully
# Chunk 468/30626 imported successfully
# Chunk 469/30626 imported successfully
# Chunk 470/30626 imported successfully
# Chunk 471/30626 imported successfully
# Chunk 472/30626 imported successfully
# Chunk 473/30626 imported successfully
# Chunk 474/30626 imported successfully
# Chunk 475/30626 imported successfully
# Chunk 476/30626 imported successfully
# Chunk 477/30626 imported successfully
# Chunk 478/30626 imported successfully
# Chunk 479/30626 imported successfully
# Chunk 480/30626 imported successfully
# Chunk 481/30626 imported successfully
# Chunk 482/30626 imported successfully
# Chunk 483/30626 imported successfully
# Chunk 484/30626 imported successfully
# Chunk 485/30626 imported successfully
# Chunk 486/30626 imported successfully
# Chunk 487/30626 imported successfully
# Chunk 488/30626 imported successfully
# Chunk 489/30626 imported successfully
# Chunk 490/30626 imported successfully
# Chunk 491/30626 imported successfully
# Chunk 492/30626 imported successfully
# Chunk 493/30626 imported successfully
# Chunk 494/30626 imported successfully
# Chunk 495/30626 imported successfully
# Chunk 496/30626 imported successfully
# Chunk 497/30626 imported successfully
# Chunk 498/30626 imported successfully
# Chunk 499/30626 imported successfully
# Chunk 500/30626 imported successfully
# Chunk 501/30626 imported successfully
# Chunk 502/30626 imported successfully
# Chunk 503/30626 imported successfully
# Chunk 504/30626 imported successfully
# Chunk 505/30626 imported successfully
# Chunk 506/30626 imported successfully
# Chunk 507/30626 imported successfully
# Chunk 508/30626 imported successfully
# Chunk 509/30626 imported successfully
# Chunk 510/30626 imported successfully
# Chunk 511/30626 imported successfully
# Chunk 512/30626 imported successfully
# Chunk 513/30626 imported successfully
# Chunk 514/30626 imported successfully
# Chunk 515/30626 imported successfully
# Chunk 516/30626 imported successfully
# Chunk 517/30626 imported successfully
# Chunk 518/30626 imported successfully
# Chunk 519/30626 imported successfully
# Chunk 520/30626 imported successfully
# Chunk 521/30626 imported successfully
# Chunk 522/30626 imported successfully
# Chunk 523/30626 imported successfully
# Chunk 524/30626 imported successfully
# Chunk 525/30626 imported successfully
# Chunk 526/30626 imported successfully
# Chunk 527/30626 imported successfully
# Chunk 528/30626 imported successfully
# Chunk 529/30626 imported successfully
# Chunk 530/30626 imported successfully
# Chunk 531/30626 imported successfully
# Chunk 532/30626 imported successfully
# Chunk 533/30626 imported successfully
# Chunk 534/30626 imported successfully
# Chunk 535/30626 imported successfully
# Chunk 536/30626 imported successfully
# Chunk 537/30626 imported successfully
# Chunk 538/30626 imported successfully
# Chunk 539/30626 imported successfully
# Chunk 540/30626 imported successfully
# Chunk 541/30626 imported successfully
# Chunk 542/30626 imported successfully
# Chunk 543/30626 imported successfully
# Chunk 544/30626 imported successfully
# Chunk 545/30626 imported successfully
# Chunk 546/30626 imported successfully
# Chunk 547/30626 imported successfully
# Chunk 548/30626 imported successfully
# Chunk 549/30626 imported successfully
# Chunk 550/30626 imported successfully
# Chunk 551/30626 imported successfully
# Chunk 552/30626 imported successfully
# Chunk 553/30626 imported successfully
# Chunk 554/30626 imported successfully
# Chunk 555/30626 imported successfully
# Chunk 556/30626 imported successfully
# Chunk 557/30626 imported successfully
# Chunk 558/30626 imported successfully
# Chunk 559/30626 imported successfully
# Chunk 560/30626 imported successfully
# Chunk 561/30626 imported successfully
# Chunk 562/30626 imported successfully
# Chunk 563/30626 imported successfully
# Chunk 564/30626 imported successfully
# Chunk 565/30626 imported successfully
# Chunk 566/30626 imported successfully
# Chunk 567/30626 imported successfully
# Chunk 568/30626 imported successfully
# Chunk 569/30626 imported successfully
# Chunk 570/30626 imported successfully
# Chunk 571/30626 imported successfully
# Chunk 572/30626 imported successfully
# Chunk 573/30626 imported successfully
# Chunk 574/30626 imported successfully
# Chunk 575/30626 imported successfully
# Chunk 576/30626 imported successfully
# Chunk 577/30626 imported successfully
# Chunk 578/30626 imported successfully
# Chunk 579/30626 imported successfully
# Chunk 580/30626 imported successfully
# Chunk 581/30626 imported successfully
# Chunk 582/30626 imported successfully
# Chunk 583/30626 imported successfully
# Chunk 584/30626 imported successfully
# Chunk 585/30626 imported successfully
# Chunk 586/30626 imported successfully
# Chunk 587/30626 imported successfully
# Chunk 588/30626 imported successfully
# Chunk 589/30626 imported successfully
# Chunk 590/30626 imported successfully
# Chunk 591/30626 imported successfully
# Chunk 592/30626 imported successfully
# Chunk 593/30626 imported successfully
# Chunk 594/30626 imported successfully
# Chunk 595/30626 imported successfully
# Chunk 596/30626 imported successfully
# Chunk 597/30626 imported successfully
# Chunk 598/30626 imported successfully
# Chunk 599/30626 imported successfully
# Chunk 600/30626 imported successfully
# Chunk 601/30626 imported successfully
# Chunk 602/30626 imported successfully
# Chunk 603/30626 imported successfully
# Chunk 604/30626 imported successfully
# Chunk 605/30626 imported successfully
# Chunk 606/30626 imported successfully
# Chunk 607/30626 imported successfully
# Chunk 608/30626 imported successfully
# Chunk 609/30626 imported successfully
# Chunk 610/30626 imported successfully
# Chunk 611/30626 imported successfully
# Chunk 612/30626 imported successfully
# Chunk 613/30626 imported successfully
# Chunk 614/30626 imported successfully
# Chunk 615/30626 imported successfully
# Chunk 616/30626 imported successfully
# Chunk 617/30626 imported successfully
# Chunk 618/30626 imported successfully
# Chunk 619/30626 imported successfully
# Chunk 620/30626 imported successfully
# Chunk 621/30626 imported successfully
# Chunk 622/30626 imported successfully
# Chunk 623/30626 imported successfully
# Chunk 624/30626 imported successfully
# Chunk 625/30626 imported successfully
# Chunk 626/30626 imported successfully
# Chunk 627/30626 imported successfully
# Chunk 628/30626 imported successfully
# Chunk 629/30626 imported successfully
# Chunk 630/30626 imported successfully
# Chunk 631/30626 imported successfully
# Chunk 632/30626 imported successfully
# Chunk 633/30626 imported successfully
# Chunk 634/30626 imported successfully
# Chunk 635/30626 imported successfully
# Chunk 636/30626 imported successfully
# Chunk 637/30626 imported successfully
# Chunk 638/30626 imported successfully
# Chunk 639/30626 imported successfully
# Chunk 640/30626 imported successfully
# Chunk 641/30626 imported successfully
# Chunk 642/30626 imported successfully
# Chunk 643/30626 imported successfully
# Chunk 644/30626 imported successfully
# Chunk 645/30626 imported successfully
# Chunk 646/30626 imported successfully
# Chunk 647/30626 imported successfully
# Chunk 648/30626 imported successfully
# Chunk 649/30626 imported successfully
# Chunk 650/30626 imported successfully
# Chunk 651/30626 imported successfully
# Chunk 652/30626 imported successfully
# Chunk 653/30626 imported successfully
# Chunk 654/30626 imported successfully
# Chunk 655/30626 imported successfully
# Chunk 656/30626 imported successfully
# Chunk 657/30626 imported successfully
# Chunk 658/30626 imported successfully
# Chunk 659/30626 imported successfully
# Chunk 660/30626 imported successfully
# Chunk 661/30626 imported successfully
# Chunk 662/30626 imported successfully
# Chunk 663/30626 imported successfully
# Chunk 664/30626 imported successfully
# Chunk 665/30626 imported successfully
# Chunk 666/30626 imported successfully
# Chunk 667/30626 imported successfully
# Chunk 668/30626 imported successfully
# Chunk 669/30626 imported successfully
# Chunk 670/30626 imported successfully
# Chunk 671/30626 imported successfully
# Chunk 672/30626 imported successfully
# Chunk 673/30626 imported successfully
# Chunk 674/30626 imported successfully
# Chunk 675/30626 imported successfully
# Chunk 676/30626 imported successfully
# Chunk 677/30626 imported successfully
# Chunk 678/30626 imported successfully
# Chunk 679/30626 imported successfully
# Chunk 680/30626 imported successfully
# Chunk 681/30626 imported successfully
# Chunk 682/30626 imported successfully
# Chunk 683/30626 imported successfully
# Chunk 684/30626 imported successfully
# Chunk 685/30626 imported successfully
# Chunk 686/30626 imported successfully
# Chunk 687/30626 imported successfully
# Chunk 688/30626 imported successfully
# Chunk 689/30626 imported successfully
# Chunk 690/30626 imported successfully
# Chunk 691/30626 imported successfully
# Chunk 692/30626 imported successfully
# Chunk 693/30626 imported successfully
# Chunk 694/30626 imported successfully
# Chunk 695/30626 imported successfully
# Chunk 696/30626 imported successfully
# Chunk 697/30626 imported successfully
# Chunk 698/30626 imported successfully
# Chunk 699/30626 imported successfully
# Chunk 700/30626 imported successfully
# Chunk 701/30626 imported successfully
# Chunk 702/30626 imported successfully
# Chunk 703/30626 imported successfully
# Chunk 704/30626 imported successfully
# Chunk 705/30626 imported successfully
# Chunk 706/30626 imported successfully
# Chunk 707/30626 imported successfully
# Chunk 708/30626 imported successfully
# Chunk 709/30626 imported successfully
# Chunk 710/30626 imported successfully
# Chunk 711/30626 imported successfully
# Chunk 712/30626 imported successfully
# Chunk 713/30626 imported successfully
# Chunk 714/30626 imported successfully
# Chunk 715/30626 imported successfully
# Chunk 716/30626 imported successfully
# Chunk 717/30626 imported successfully
# Chunk 718/30626 imported successfully
# Chunk 719/30626 imported successfully
# Chunk 720/30626 imported successfully
# Chunk 721/30626 imported successfully
# Chunk 722/30626 imported successfully
# Chunk 723/30626 imported successfully
# Chunk 724/30626 imported successfully
# Chunk 725/30626 imported successfully
# Chunk 726/30626 imported successfully
# Chunk 727/30626 imported successfully
# Chunk 728/30626 imported successfully
# Chunk 729/30626 imported successfully
# Chunk 730/30626 imported successfully
# Chunk 731/30626 imported successfully
# Chunk 732/30626 imported successfully
# Chunk 733/30626 imported successfully
# Chunk 734/30626 imported successfully
# Chunk 735/30626 imported successfully
# Chunk 736/30626 imported successfully
# Chunk 737/30626 imported successfully
# Chunk 738/30626 imported successfully
# Chunk 739/30626 imported successfully
# Chunk 740/30626 imported successfully
# Chunk 741/30626 imported successfully
# Chunk 742/30626 imported successfully
# Chunk 743/30626 imported successfully
# Chunk 744/30626 imported successfully
# Chunk 745/30626 imported successfully
# Chunk 746/30626 imported successfully
# Chunk 747/30626 imported successfully
# Chunk 748/30626 imported successfully
# Chunk 749/30626 imported successfully
# Chunk 750/30626 imported successfully
# Chunk 751/30626 imported successfully
# Chunk 752/30626 imported successfully
# Chunk 753/30626 imported successfully
# Chunk 754/30626 imported successfully
# Chunk 755/30626 imported successfully
# Chunk 756/30626 imported successfully
# Chunk 757/30626 imported successfully
# Chunk 758/30626 imported successfully
# Chunk 759/30626 imported successfully
# Chunk 760/30626 imported successfully
# Chunk 761/30626 imported successfully
# Chunk 762/30626 imported successfully
# Chunk 763/30626 imported successfully
# Chunk 764/30626 imported successfully
# Chunk 765/30626 imported successfully
# Chunk 766/30626 imported successfully
# Chunk 767/30626 imported successfully
# Chunk 768/30626 imported successfully
# Chunk 769/30626 imported successfully
# Chunk 770/30626 imported successfully
# Chunk 771/30626 imported successfully
# Chunk 772/30626 imported successfully
# Chunk 773/30626 imported successfully
# Chunk 774/30626 imported successfully
# Chunk 775/30626 imported successfully
# Chunk 776/30626 imported successfully
# Chunk 777/30626 imported successfully
# Chunk 778/30626 imported successfully
# Chunk 779/30626 imported successfully
# Chunk 780/30626 imported successfully
# Chunk 781/30626 imported successfully
# Chunk 782/30626 imported successfully
# Chunk 783/30626 imported successfully
# Chunk 784/30626 imported successfully
# Chunk 785/30626 imported successfully
# Chunk 786/30626 imported successfully
# Chunk 787/30626 imported successfully
# Chunk 788/30626 imported successfully
# Chunk 789/30626 imported successfully
# Chunk 790/30626 imported successfully
# Chunk 791/30626 imported successfully
# Chunk 792/30626 imported successfully
# Chunk 793/30626 imported successfully
# Chunk 794/30626 imported successfully
# Chunk 795/30626 imported successfully
# Chunk 796/30626 imported successfully
# Chunk 797/30626 imported successfully
# Chunk 798/30626 imported successfully
# Chunk 799/30626 imported successfully
# Chunk 800/30626 imported successfully
# Chunk 801/30626 imported successfully
# Chunk 802/30626 imported successfully
# Chunk 803/30626 imported successfully
# Chunk 804/30626 imported successfully
# Chunk 805/30626 imported successfully
# Chunk 806/30626 imported successfully
# Chunk 807/30626 imported successfully
# Chunk 808/30626 imported successfully
# Chunk 809/30626 imported successfully
# Chunk 810/30626 imported successfully
# Chunk 811/30626 imported successfully
# Chunk 812/30626 imported successfully
# Chunk 813/30626 imported successfully
# Chunk 814/30626 imported successfully
# Chunk 815/30626 imported successfully
# Chunk 816/30626 imported successfully
# Chunk 817/30626 imported successfully
# Chunk 818/30626 imported successfully
# Chunk 819/30626 imported successfully
# Chunk 820/30626 imported successfully
# Chunk 821/30626 imported successfully
# Chunk 822/30626 imported successfully
# Chunk 823/30626 imported successfully
# Chunk 824/30626 imported successfully
# Chunk 825/30626 imported successfully
# Chunk 826/30626 imported successfully
# Chunk 827/30626 imported successfully
# Chunk 828/30626 imported successfully
# Chunk 829/30626 imported successfully
# Chunk 830/30626 imported successfully
# Chunk 831/30626 imported successfully
# Chunk 832/30626 imported successfully
# Chunk 833/30626 imported successfully
# Chunk 834/30626 imported successfully
# Chunk 835/30626 imported successfully
# Chunk 836/30626 imported successfully
# Chunk 837/30626 imported successfully
# Chunk 838/30626 imported successfully
# Chunk 839/30626 imported successfully
# Chunk 840/30626 imported successfully
# Chunk 841/30626 imported successfully
# Chunk 842/30626 imported successfully
# Chunk 843/30626 imported successfully
# Chunk 844/30626 imported successfully
# Chunk 845/30626 imported successfully
# Chunk 846/30626 imported successfully
# Chunk 847/30626 imported successfully
# Chunk 848/30626 imported successfully
# Chunk 849/30626 imported successfully
# Chunk 850/30626 imported successfully
# Chunk 851/30626 imported successfully
# Chunk 852/30626 imported successfully
# Chunk 853/30626 imported successfully
# Chunk 854/30626 imported successfully
# Chunk 855/30626 imported successfully
# Chunk 856/30626 imported successfully
# Chunk 857/30626 imported successfully
# Chunk 858/30626 imported successfully
# Chunk 859/30626 imported successfully
# Chunk 860/30626 imported successfully
# Chunk 861/30626 imported successfully
# Chunk 862/30626 imported successfully
# Chunk 863/30626 imported successfully
# Chunk 864/30626 imported successfully
# Chunk 865/30626 imported successfully
# Chunk 866/30626 imported successfully
# Chunk 867/30626 imported successfully
# Chunk 868/30626 imported successfully
# Chunk 869/30626 imported successfully
# Chunk 870/30626 imported successfully
# Chunk 871/30626 imported successfully
# Chunk 872/30626 imported successfully
# Chunk 873/30626 imported successfully
# Chunk 874/30626 imported successfully
# Chunk 875/30626 imported successfully
# Chunk 876/30626 imported successfully
# Chunk 877/30626 imported successfully
# Chunk 878/30626 imported successfully
# Chunk 879/30626 imported successfully
# Chunk 880/30626 imported successfully
# Chunk 881/30626 imported successfully
# Chunk 882/30626 imported successfully
# Chunk 883/30626 imported successfully
# Chunk 884/30626 imported successfully
# Chunk 885/30626 imported successfully
# Chunk 886/30626 imported successfully
# Chunk 887/30626 imported successfully
# Chunk 888/30626 imported successfully
# Chunk 889/30626 imported successfully
# Chunk 890/30626 imported successfully
# Chunk 891/30626 imported successfully
# Chunk 892/30626 imported successfully
# Chunk 893/30626 imported successfully
# Chunk 894/30626 imported successfully
# Chunk 895/30626 imported successfully
# Chunk 896/30626 imported successfully
# Chunk 897/30626 imported successfully
# Chunk 898/30626 imported successfully
# Chunk 899/30626 imported successfully
# Chunk 900/30626 imported successfully
# Chunk 901/30626 imported successfully
# Chunk 902/30626 imported successfully
# Chunk 903/30626 imported successfully
# Chunk 904/30626 imported successfully
# Chunk 905/30626 imported successfully
# Chunk 906/30626 imported successfully
# Chunk 907/30626 imported successfully
# Chunk 908/30626 imported successfully
# Chunk 909/30626 imported successfully
# Chunk 910/30626 imported successfully
# Chunk 911/30626 imported successfully
# Chunk 912/30626 imported successfully
# Chunk 913/30626 imported successfully
# Chunk 914/30626 imported successfully
# Chunk 915/30626 imported successfully
# Chunk 916/30626 imported successfully
# Chunk 917/30626 imported successfully
# Chunk 918/30626 imported successfully
# Chunk 919/30626 imported successfully
# Chunk 920/30626 imported successfully
# Chunk 921/30626 imported successfully
# Chunk 922/30626 imported successfully
# Chunk 923/30626 imported successfully
# Chunk 924/30626 imported successfully
# Chunk 925/30626 imported successfully
# Chunk 926/30626 imported successfully
# Chunk 927/30626 imported successfully
# Chunk 928/30626 imported successfully
# Chunk 929/30626 imported successfully
# Chunk 930/30626 imported successfully
# Chunk 931/30626 imported successfully
# Chunk 932/30626 imported successfully
# Chunk 933/30626 imported successfully
# Chunk 934/30626 imported successfully
# Chunk 935/30626 imported successfully
# Chunk 936/30626 imported successfully
# Chunk 937/30626 imported successfully
# Chunk 938/30626 imported successfully
# Chunk 939/30626 imported successfully
# Chunk 940/30626 imported successfully
# Chunk 941/30626 imported successfully
# Chunk 942/30626 imported successfully
# Chunk 943/30626 imported successfully
# Chunk 944/30626 imported successfully
# Chunk 945/30626 imported successfully
# Chunk 946/30626 imported successfully
# Chunk 947/30626 imported successfully
# Chunk 948/30626 imported successfully
# Chunk 949/30626 imported successfully
# Chunk 950/30626 imported successfully
# Chunk 951/30626 imported successfully
# Chunk 952/30626 imported successfully
# Chunk 953/30626 imported successfully
# Chunk 954/30626 imported successfully
# Chunk 955/30626 imported successfully
# Chunk 956/30626 imported successfully
# Chunk 957/30626 imported successfully
# Chunk 958/30626 imported successfully
# Chunk 959/30626 imported successfully
# Chunk 960/30626 imported successfully
# Chunk 961/30626 imported successfully
# Chunk 962/30626 imported successfully
# Chunk 963/30626 imported successfully
# Chunk 964/30626 imported successfully
# Chunk 965/30626 imported successfully
# Chunk 966/30626 imported successfully
# Chunk 967/30626 imported successfully
# Chunk 968/30626 imported successfully
# Chunk 969/30626 imported successfully
# Chunk 970/30626 imported successfully
# Chunk 971/30626 imported successfully
# Chunk 972/30626 imported successfully
# Chunk 973/30626 imported successfully
# Chunk 974/30626 imported successfully
# Chunk 975/30626 imported successfully
# Chunk 976/30626 imported successfully
# Chunk 977/30626 imported successfully
# Chunk 978/30626 imported successfully
# Chunk 979/30626 imported successfully
# Chunk 980/30626 imported successfully
# Chunk 981/30626 imported successfully
# Chunk 982/30626 imported successfully
# Chunk 983/30626 imported successfully
# Chunk 984/30626 imported successfully
# Chunk 985/30626 imported successfully
# Chunk 986/30626 imported successfully
# Chunk 987/30626 imported successfully
# Chunk 988/30626 imported successfully
# Chunk 989/30626 imported successfully
# Chunk 990/30626 imported successfully
# Chunk 991/30626 imported successfully
# Chunk 992/30626 imported successfully
# Chunk 993/30626 imported successfully
# Chunk 994/30626 imported successfully
# Chunk 995/30626 imported successfully
# Chunk 996/30626 imported successfully
# Chunk 997/30626 imported successfully
# Chunk 998/30626 imported successfully
# Chunk 999/30626 imported successfully
# Chunk 1000/30626 imported successfully
# Chunk 1001/30626 imported successfully
# Chunk 1002/30626 imported successfully
# Chunk 1003/30626 imported successfully
# Chunk 1004/30626 imported successfully
# Chunk 1005/30626 imported successfully
# Chunk 1006/30626 imported successfully
# Chunk 1007/30626 imported successfully
# Chunk 1008/30626 imported successfully
# Chunk 1009/30626 imported successfully
# Chunk 1010/30626 imported successfully
# Chunk 1011/30626 imported successfully
# Chunk 1012/30626 imported successfully
# Chunk 1013/30626 imported successfully
# Chunk 1014/30626 imported successfully
# Chunk 1015/30626 imported successfully
# Chunk 1016/30626 imported successfully
# Chunk 1017/30626 imported successfully
# Chunk 1018/30626 imported successfully
# Chunk 1019/30626 imported successfully
# Chunk 1020/30626 imported successfully
# Chunk 1021/30626 imported successfully
# Chunk 1022/30626 imported successfully
# Chunk 1023/30626 imported successfully
# Chunk 1024/30626 imported successfully
# Chunk 1025/30626 imported successfully
# Chunk 1026/30626 imported successfully
# Chunk 1027/30626 imported successfully
# Chunk 1028/30626 imported successfully
# Chunk 1029/30626 imported successfully
# Chunk 1030/30626 imported successfully
# Chunk 1031/30626 imported successfully
# Chunk 1032/30626 imported successfully
# Chunk 1033/30626 imported successfully
# Chunk 1034/30626 imported successfully
# Chunk 1035/30626 imported successfully
# Chunk 1036/30626 imported successfully
# Chunk 1037/30626 imported successfully
# Chunk 1038/30626 imported successfully
# Chunk 1039/30626 imported successfully
# Chunk 1040/30626 imported successfully
# Chunk 1041/30626 imported successfully
# Chunk 1042/30626 imported successfully
# Chunk 1043/30626 imported successfully
# Chunk 1044/30626 imported successfully
# Chunk 1045/30626 imported successfully
# Chunk 1046/30626 imported successfully
# Chunk 1047/30626 imported successfully
# Chunk 1048/30626 imported successfully
# Chunk 1049/30626 imported successfully
# Chunk 1050/30626 imported successfully
# Chunk 1051/30626 imported successfully
# Chunk 1052/30626 imported successfully
# Chunk 1053/30626 imported successfully
# Chunk 1054/30626 imported successfully
# Chunk 1055/30626 imported successfully
# Chunk 1056/30626 imported successfully
# Chunk 1057/30626 imported successfully
# Chunk 1058/30626 imported successfully
# Chunk 1059/30626 imported successfully
# Chunk 1060/30626 imported successfully
# Chunk 1061/30626 imported successfully
# Chunk 1062/30626 imported successfully
# Chunk 1063/30626 imported successfully
# Chunk 1064/30626 imported successfully
# Chunk 1065/30626 imported successfully
# Chunk 1066/30626 imported successfully
# Chunk 1067/30626 imported successfully
# Chunk 1068/30626 imported successfully
# Chunk 1069/30626 imported successfully
# Chunk 1070/30626 imported successfully
# Chunk 1071/30626 imported successfully
# Chunk 1072/30626 imported successfully
# Chunk 1073/30626 imported successfully
# Chunk 1074/30626 imported successfully
# Chunk 1075/30626 imported successfully
# Chunk 1076/30626 imported successfully
# Chunk 1077/30626 imported successfully
# Chunk 1078/30626 imported successfully
# Chunk 1079/30626 imported successfully
# Chunk 1080/30626 imported successfully
# Chunk 1081/30626 imported successfully
# Chunk 1082/30626 imported successfully
# Chunk 1083/30626 imported successfully
# Chunk 1084/30626 imported successfully
# Chunk 1085/30626 imported successfully
# Chunk 1086/30626 imported successfully
# Chunk 1087/30626 imported successfully
# Chunk 1088/30626 imported successfully
# Chunk 1089/30626 imported successfully
# Chunk 1090/30626 imported successfully
# Chunk 1091/30626 imported successfully
# Chunk 1092/30626 imported successfully
# Chunk 1093/30626 imported successfully
# Chunk 1094/30626 imported successfully
# Chunk 1095/30626 imported successfully
# Chunk 1096/30626 imported successfully
# Chunk 1097/30626 imported successfully
# Chunk 1098/30626 imported successfully
# Chunk 1099/30626 imported successfully
# Chunk 1100/30626 imported successfully
# Chunk 1101/30626 imported successfully
# Chunk 1102/30626 imported successfully
# Chunk 1103/30626 imported successfully
# Chunk 1104/30626 imported successfully
# Chunk 1105/30626 imported successfully
# Chunk 1106/30626 imported successfully
# Chunk 1107/30626 imported successfully
# Chunk 1108/30626 imported successfully
# Chunk 1109/30626 imported successfully
# Chunk 1110/30626 imported successfully
# Chunk 1111/30626 imported successfully
# Chunk 1112/30626 imported successfully
# Chunk 1113/30626 imported successfully
# Chunk 1114/30626 imported successfully
# Chunk 1115/30626 imported successfully
# Chunk 1116/30626 imported successfully
# Chunk 1117/30626 imported successfully
# Chunk 1118/30626 imported successfully
# Chunk 1119/30626 imported successfully
# Chunk 1120/30626 imported successfully
# Chunk 1121/30626 imported successfully
# Chunk 1122/30626 imported successfully
# Chunk 1123/30626 imported successfully
# Chunk 1124/30626 imported successfully
# Chunk 1125/30626 imported successfully
# Chunk 1126/30626 imported successfully
# Chunk 1127/30626 imported successfully
# Chunk 1128/30626 imported successfully
# Chunk 1129/30626 imported successfully
# Chunk 1130/30626 imported successfully
# Chunk 1131/30626 imported successfully
# Chunk 1132/30626 imported successfully
# Chunk 1133/30626 imported successfully
# Chunk 1134/30626 imported successfully
# Chunk 1135/30626 imported successfully
# Chunk 1136/30626 imported successfully
# Chunk 1137/30626 imported successfully
# Chunk 1138/30626 imported successfully
# Chunk 1139/30626 imported successfully
# Chunk 1140/30626 imported successfully
# Chunk 1141/30626 imported successfully
# Chunk 1142/30626 imported successfully
# Chunk 1143/30626 imported successfully
# Chunk 1144/30626 imported successfully
# Chunk 1145/30626 imported successfully
# Chunk 1146/30626 imported successfully
# Chunk 1147/30626 imported successfully
# Chunk 1148/30626 imported successfully
# Chunk 1149/30626 imported successfully
# Chunk 1150/30626 imported successfully
# Chunk 1151/30626 imported successfully
# Chunk 1152/30626 imported successfully
# Chunk 1153/30626 imported successfully
# Chunk 1154/30626 imported successfully
# Chunk 1155/30626 imported successfully
# Chunk 1156/30626 imported successfully
# Chunk 1157/30626 imported successfully
# Chunk 1158/30626 imported successfully
# Chunk 1159/30626 imported successfully
# Chunk 1160/30626 imported successfully
# Chunk 1161/30626 imported successfully
# Chunk 1162/30626 imported successfully
# Chunk 1163/30626 imported successfully
# Chunk 1164/30626 imported successfully
# Chunk 1165/30626 imported successfully
# Chunk 1166/30626 imported successfully
# Chunk 1167/30626 imported successfully
# Chunk 1168/30626 imported successfully
# Chunk 1169/30626 imported successfully
# Chunk 1170/30626 imported successfully
# Chunk 1171/30626 imported successfully
# Chunk 1172/30626 imported successfully
# Chunk 1173/30626 imported successfully
# Chunk 1174/30626 imported successfully
# Chunk 1175/30626 imported successfully
# Chunk 1176/30626 imported successfully
# Chunk 1177/30626 imported successfully
# Chunk 1178/30626 imported successfully
# Chunk 1179/30626 imported successfully
# Chunk 1180/30626 imported successfully
# Chunk 1181/30626 imported successfully
# Chunk 1182/30626 imported successfully
# Chunk 1183/30626 imported successfully
# Chunk 1184/30626 imported successfully
# Chunk 1185/30626 imported successfully
# Chunk 1186/30626 imported successfully
# Chunk 1187/30626 imported successfully
# Chunk 1188/30626 imported successfully
# Chunk 1189/30626 imported successfully
# Chunk 1190/30626 imported successfully
# Chunk 1191/30626 imported successfully
# Chunk 1192/30626 imported successfully
# Chunk 1193/30626 imported successfully
# Chunk 1194/30626 imported successfully
# Chunk 1195/30626 imported successfully
# Chunk 1196/30626 imported successfully
# Chunk 1197/30626 imported successfully
# Chunk 1198/30626 imported successfully
# Chunk 1199/30626 imported successfully
# Chunk 1200/30626 imported successfully
# Chunk 1201/30626 imported successfully
# Chunk 1202/30626 imported successfully
# Chunk 1203/30626 imported successfully
# Chunk 1204/30626 imported successfully
# Chunk 1205/30626 imported successfully
# Chunk 1206/30626 imported successfully
# Chunk 1207/30626 imported successfully
# Chunk 1208/30626 imported successfully
# Chunk 1209/30626 imported successfully
# Chunk 1210/30626 imported successfully
# Chunk 1211/30626 imported successfully
# Chunk 1212/30626 imported successfully
# Chunk 1213/30626 imported successfully
# Chunk 1214/30626 imported successfully
# Chunk 1215/30626 imported successfully
# Chunk 1216/30626 imported successfully
# Chunk 1217/30626 imported successfully
# Chunk 1218/30626 imported successfully
# Chunk 1219/30626 imported successfully
# Chunk 1220/30626 imported successfully
# Chunk 1221/30626 imported successfully
# Chunk 1222/30626 imported successfully
# Chunk 1223/30626 imported successfully
# Chunk 1224/30626 imported successfully
# Chunk 1225/30626 imported successfully
# Chunk 1226/30626 imported successfully
# Chunk 1227/30626 imported successfully
# Chunk 1228/30626 imported successfully
# Chunk 1229/30626 imported successfully
# Chunk 1230/30626 imported successfully
# Chunk 1231/30626 imported successfully
# Chunk 1232/30626 imported successfully
# Chunk 1233/30626 imported successfully
# Chunk 1234/30626 imported successfully
# Chunk 1235/30626 imported successfully
# Chunk 1236/30626 imported successfully
# Chunk 1237/30626 imported successfully
# Chunk 1238/30626 imported successfully
# Chunk 1239/30626 imported successfully
# Chunk 1240/30626 imported successfully
# Chunk 1241/30626 imported successfully
# Chunk 1242/30626 imported successfully
# Chunk 1243/30626 imported successfully
# Chunk 1244/30626 imported successfully
# Chunk 1245/30626 imported successfully
# Chunk 1246/30626 imported successfully
# Chunk 1247/30626 imported successfully
# Chunk 1248/30626 imported successfully
# Chunk 1249/30626 imported successfully
# Chunk 1250/30626 imported successfully
# Chunk 1251/30626 imported successfully
# Chunk 1252/30626 imported successfully
# Chunk 1253/30626 imported successfully
# Chunk 1254/30626 imported successfully
# Chunk 1255/30626 imported successfully
# Chunk 1256/30626 imported successfully
# Chunk 1257/30626 imported successfully
# Chunk 1258/30626 imported successfully
# Chunk 1259/30626 imported successfully
# ...
# Chunk 30227/30626 imported successfully
# Chunk 30228/30626 imported successfully
# Chunk 30229/30626 imported successfully
# Chunk 30230/30626 imported successfully
# Chunk 30231/30626 imported successfully
# Chunk 30232/30626 imported successfully
# Chunk 30233/30626 imported successfully
# Chunk 30234/30626 imported successfully
# Chunk 30235/30626 imported successfully
# Chunk 30236/30626 imported successfully
# Chunk 30237/30626 imported successfully
# Chunk 30238/30626 imported successfully
# Chunk 30239/30626 imported successfully
# Chunk 30240/30626 imported successfully
# Chunk 30241/30626 imported successfully
# Chunk 30242/30626 imported successfully
# Chunk 30243/30626 imported successfully
# Chunk 30244/30626 imported successfully
# Chunk 30245/30626 imported successfully
# Chunk 30246/30626 imported successfully
# Chunk 30247/30626 imported successfully
# Chunk 30248/30626 imported successfully
# Chunk 30249/30626 imported successfully
# Chunk 30250/30626 imported successfully
# Chunk 30251/30626 imported successfully
# Chunk 30252/30626 imported successfully
# Chunk 30253/30626 imported successfully
# Chunk 30254/30626 imported successfully
# Chunk 30255/30626 imported successfully
# Chunk 30256/30626 imported successfully
# Chunk 30257/30626 imported successfully
# Chunk 30258/30626 imported successfully
# Chunk 30259/30626 imported successfully
# Chunk 30260/30626 imported successfully
# Chunk 30261/30626 imported successfully
# Chunk 30262/30626 imported successfully
# Chunk 30263/30626 imported successfully
# Chunk 30264/30626 imported successfully
# Chunk 30265/30626 imported successfully
# Chunk 30266/30626 imported successfully
# Chunk 30267/30626 imported successfully
# Chunk 30268/30626 imported successfully
# Chunk 30269/30626 imported successfully
# Chunk 30270/30626 imported successfully
# Chunk 30271/30626 imported successfully
# Chunk 30272/30626 imported successfully
# Chunk 30273/30626 imported successfully
# Chunk 30274/30626 imported successfully
# Chunk 30275/30626 imported successfully
# Chunk 30276/30626 imported successfully
# Chunk 30277/30626 imported successfully
# Chunk 30278/30626 imported successfully
# Chunk 30279/30626 imported successfully
# Chunk 30280/30626 imported successfully
# Chunk 30281/30626 imported successfully
# Chunk 30282/30626 imported successfully
# Chunk 30283/30626 imported successfully
# Chunk 30284/30626 imported successfully
# Chunk 30285/30626 imported successfully
# Chunk 30286/30626 imported successfully
# Chunk 30287/30626 imported successfully
# Chunk 30288/30626 imported successfully
# Chunk 30289/30626 imported successfully
# Chunk 30290/30626 imported successfully
# Chunk 30291/30626 imported successfully
# Chunk 30292/30626 imported successfully
# Chunk 30293/30626 imported successfully
# Chunk 30294/30626 imported successfully
# Chunk 30295/30626 imported successfully
# Chunk 30296/30626 imported successfully
# Chunk 30297/30626 imported successfully
# Chunk 30298/30626 imported successfully
# Chunk 30299/30626 imported successfully
# Chunk 30300/30626 imported successfully
# Chunk 30301/30626 imported successfully
# Chunk 30302/30626 imported successfully
# Chunk 30303/30626 imported successfully
# Chunk 30304/30626 imported successfully
# Chunk 30305/30626 imported successfully
# Chunk 30306/30626 imported successfully
# Chunk 30307/30626 imported successfully
# Chunk 30308/30626 imported successfully
# Chunk 30309/30626 imported successfully
# Chunk 30310/30626 imported successfully
# Chunk 30311/30626 imported successfully
# Chunk 30312/30626 imported successfully
# Chunk 30313/30626 imported successfully
# Chunk 30314/30626 imported successfully
# Chunk 30315/30626 imported successfully
# Chunk 30316/30626 imported successfully
# Chunk 30317/30626 imported successfully
# Chunk 30318/30626 imported successfully
# Chunk 30319/30626 imported successfully
# Chunk 30320/30626 imported successfully
# Chunk 30321/30626 imported successfully
# Chunk 30322/30626 imported successfully
# Chunk 30323/30626 imported successfully
# Chunk 30324/30626 imported successfully
# Chunk 30325/30626 imported successfully
# Chunk 30326/30626 imported successfully
# Chunk 30327/30626 imported successfully
# Chunk 30328/30626 imported successfully
# Chunk 30329/30626 imported successfully
# Chunk 30330/30626 imported successfully
# Chunk 30331/30626 imported successfully
# Chunk 30332/30626 imported successfully
# Chunk 30333/30626 imported successfully
# Chunk 30334/30626 imported successfully
# Chunk 30335/30626 imported successfully
# Chunk 30336/30626 imported successfully
# Chunk 30337/30626 imported successfully
# Chunk 30338/30626 imported successfully
# Chunk 30339/30626 imported successfully
# Chunk 30340/30626 imported successfully
# Chunk 30341/30626 imported successfully
# Chunk 30342/30626 imported successfully
# Chunk 30343/30626 imported successfully
# Chunk 30344/30626 imported successfully
# Chunk 30345/30626 imported successfully
# Chunk 30346/30626 imported successfully
# Chunk 30347/30626 imported successfully
# Chunk 30348/30626 imported successfully
# Chunk 30349/30626 imported successfully
# Chunk 30350/30626 imported successfully
# Chunk 30351/30626 imported successfully
# Chunk 30352/30626 imported successfully
# Chunk 30353/30626 imported successfully
# Chunk 30354/30626 imported successfully
# Chunk 30355/30626 imported successfully
# Chunk 30356/30626 imported successfully
# Chunk 30357/30626 imported successfully
# Chunk 30358/30626 imported successfully
# Chunk 30359/30626 imported successfully
# Chunk 30360/30626 imported successfully
# Chunk 30361/30626 imported successfully
# Chunk 30362/30626 imported successfully
# Chunk 30363/30626 imported successfully
# Chunk 30364/30626 imported successfully
# Chunk 30365/30626 imported successfully
# Chunk 30366/30626 imported successfully
# Chunk 30367/30626 imported successfully
# Chunk 30368/30626 imported successfully
# Chunk 30369/30626 imported successfully
# Chunk 30370/30626 imported successfully
# Chunk 30371/30626 imported successfully
# Chunk 30372/30626 imported successfully
# Chunk 30373/30626 imported successfully
# Chunk 30374/30626 imported successfully
# Chunk 30375/30626 imported successfully
# Chunk 30376/30626 imported successfully
# Chunk 30377/30626 imported successfully
# Chunk 30378/30626 imported successfully
# Chunk 30379/30626 imported successfully
# Chunk 30380/30626 imported successfully
# Chunk 30381/30626 imported successfully
# Chunk 30382/30626 imported successfully
# Chunk 30383/30626 imported successfully
# Chunk 30384/30626 imported successfully
# Chunk 30385/30626 imported successfully
# Chunk 30386/30626 imported successfully
# Chunk 30387/30626 imported successfully
# Chunk 30388/30626 imported successfully
# Chunk 30389/30626 imported successfully
# Chunk 30390/30626 imported successfully
# Chunk 30391/30626 imported successfully
# Chunk 30392/30626 imported successfully
# Chunk 30393/30626 imported successfully
# Chunk 30394/30626 imported successfully
# Chunk 30395/30626 imported successfully
# Chunk 30396/30626 imported successfully
# Chunk 30397/30626 imported successfully
# Chunk 30398/30626 imported successfully
# Chunk 30399/30626 imported successfully
# Chunk 30400/30626 imported successfully
# Chunk 30401/30626 imported successfully
# Chunk 30402/30626 imported successfully
# Chunk 30403/30626 imported successfully
# Chunk 30404/30626 imported successfully
# Chunk 30405/30626 imported successfully
# Chunk 30406/30626 imported successfully
# Chunk 30407/30626 imported successfully
# Chunk 30408/30626 imported successfully
# Chunk 30409/30626 imported successfully
# Chunk 30410/30626 imported successfully
# Chunk 30411/30626 imported successfully
# Chunk 30412/30626 imported successfully
# Chunk 30413/30626 imported successfully
# Chunk 30414/30626 imported successfully
# Chunk 30415/30626 imported successfully
# Chunk 30416/30626 imported successfully
# Chunk 30417/30626 imported successfully
# Chunk 30418/30626 imported successfully
# Chunk 30419/30626 imported successfully
# Chunk 30420/30626 imported successfully
# Chunk 30421/30626 imported successfully
# Chunk 30422/30626 imported successfully
# Chunk 30423/30626 imported successfully
# Chunk 30424/30626 imported successfully
# Chunk 30425/30626 imported successfully
# Chunk 30426/30626 imported successfully
# Chunk 30427/30626 imported successfully
# Chunk 30428/30626 imported successfully
# Chunk 30429/30626 imported successfully
# Chunk 30430/30626 imported successfully
# Chunk 30431/30626 imported successfully
# Chunk 30432/30626 imported successfully
# Chunk 30433/30626 imported successfully
# Chunk 30434/30626 imported successfully
# Chunk 30435/30626 imported successfully
# Chunk 30436/30626 imported successfully
# Chunk 30437/30626 imported successfully
# Chunk 30438/30626 imported successfully
# Chunk 30439/30626 imported successfully
# Chunk 30440/30626 imported successfully
# Chunk 30441/30626 imported successfully
# Chunk 30442/30626 imported successfully
# Chunk 30443/30626 imported successfully
# Chunk 30444/30626 imported successfully
# Chunk 30445/30626 imported successfully
# Chunk 30446/30626 imported successfully
# Chunk 30447/30626 imported successfully
# Chunk 30448/30626 imported successfully
# Chunk 30449/30626 imported successfully
# Chunk 30450/30626 imported successfully
# Chunk 30451/30626 imported successfully
# Chunk 30452/30626 imported successfully
# Chunk 30453/30626 imported successfully
# Chunk 30454/30626 imported successfully
# Chunk 30455/30626 imported successfully
# Chunk 30456/30626 imported successfully
# Chunk 30457/30626 imported successfully
# Chunk 30458/30626 imported successfully
# Chunk 30459/30626 imported successfully
# Chunk 30460/30626 imported successfully
# Chunk 30461/30626 imported successfully
# Chunk 30462/30626 imported successfully
# Chunk 30463/30626 imported successfully
# Chunk 30464/30626 imported successfully
# Chunk 30465/30626 imported successfully
# Chunk 30466/30626 imported successfully
# Chunk 30467/30626 imported successfully
# Chunk 30468/30626 imported successfully
# Chunk 30469/30626 imported successfully
# Chunk 30470/30626 imported successfully
# Chunk 30471/30626 imported successfully
# Chunk 30472/30626 imported successfully
# Chunk 30473/30626 imported successfully
# Chunk 30474/30626 imported successfully
# Chunk 30475/30626 imported successfully
# Chunk 30476/30626 imported successfully
# Chunk 30477/30626 imported successfully
# Chunk 30478/30626 imported successfully
# Chunk 30479/30626 imported successfully
# Chunk 30480/30626 imported successfully
# Chunk 30481/30626 imported successfully
# Chunk 30482/30626 imported successfully
# Chunk 30483/30626 imported successfully
# Chunk 30484/30626 imported successfully
# Chunk 30485/30626 imported successfully
# Chunk 30486/30626 imported successfully
# Chunk 30487/30626 imported successfully
# Chunk 30488/30626 imported successfully
# Chunk 30489/30626 imported successfully
# Chunk 30490/30626 imported successfully
# Chunk 30491/30626 imported successfully
# Chunk 30492/30626 imported successfully
# Chunk 30493/30626 imported successfully
# Chunk 30494/30626 imported successfully
# Chunk 30495/30626 imported successfully
# Chunk 30496/30626 imported successfully
# Chunk 30497/30626 imported successfully
# Chunk 30498/30626 imported successfully
# Chunk 30499/30626 imported successfully
# Chunk 30500/30626 imported successfully
# Chunk 30501/30626 imported successfully
# Chunk 30502/30626 imported successfully
# Chunk 30503/30626 imported successfully
# Chunk 30504/30626 imported successfully
# Chunk 30505/30626 imported successfully
# Chunk 30506/30626 imported successfully
# Chunk 30507/30626 imported successfully
# Chunk 30508/30626 imported successfully
# Chunk 30509/30626 imported successfully
# Chunk 30510/30626 imported successfully
# Chunk 30511/30626 imported successfully
# Chunk 30512/30626 imported successfully
# Chunk 30513/30626 imported successfully
# Chunk 30514/30626 imported successfully
# Chunk 30515/30626 imported successfully
# Chunk 30516/30626 imported successfully
# Chunk 30517/30626 imported successfully
# Chunk 30518/30626 imported successfully
# Chunk 30519/30626 imported successfully
# Chunk 30520/30626 imported successfully
# Chunk 30521/30626 imported successfully
# Chunk 30522/30626 imported successfully
# Chunk 30523/30626 imported successfully
# Chunk 30524/30626 imported successfully
# Chunk 30525/30626 imported successfully
# Chunk 30526/30626 imported successfully
# Chunk 30527/30626 imported successfully
# Chunk 30528/30626 imported successfully
# Chunk 30529/30626 imported successfully
# Chunk 30530/30626 imported successfully
# Chunk 30531/30626 imported successfully
# Chunk 30532/30626 imported successfully
# Chunk 30533/30626 imported successfully
# Chunk 30534/30626 imported successfully
# Chunk 30535/30626 imported successfully
# Chunk 30536/30626 imported successfully
# Chunk 30537/30626 imported successfully
# Chunk 30538/30626 imported successfully
# Chunk 30539/30626 imported successfully
# Chunk 30540/30626 imported successfully
# Chunk 30541/30626 imported successfully
# Chunk 30542/30626 imported successfully
# Chunk 30543/30626 imported successfully
# Chunk 30544/30626 imported successfully
# Chunk 30545/30626 imported successfully
# Chunk 30546/30626 imported successfully
# Chunk 30547/30626 imported successfully
# Chunk 30548/30626 imported successfully
# Chunk 30549/30626 imported successfully
# Chunk 30550/30626 imported successfully
# Chunk 30551/30626 imported successfully
# Chunk 30552/30626 imported successfully
# Chunk 30553/30626 imported successfully
# Chunk 30554/30626 imported successfully
# Chunk 30555/30626 imported successfully
# Chunk 30556/30626 imported successfully
# Chunk 30557/30626 imported successfully
# Chunk 30558/30626 imported successfully
# Chunk 30559/30626 imported successfully
# Chunk 30560/30626 imported successfully
# Chunk 30561/30626 imported successfully
# Chunk 30562/30626 imported successfully
# Chunk 30563/30626 imported successfully
# Chunk 30564/30626 imported successfully
# Chunk 30565/30626 imported successfully
# Chunk 30566/30626 imported successfully
# Chunk 30567/30626 imported successfully
# Chunk 30568/30626 imported successfully
# Chunk 30569/30626 imported successfully
# Chunk 30570/30626 imported successfully
# Chunk 30571/30626 imported successfully
# Chunk 30572/30626 imported successfully
# Chunk 30573/30626 imported successfully
# Chunk 30574/30626 imported successfully
# Chunk 30575/30626 imported successfully
# Chunk 30576/30626 imported successfully
# Chunk 30577/30626 imported successfully
# Chunk 30578/30626 imported successfully
# Chunk 30579/30626 imported successfully
# Chunk 30580/30626 imported successfully
# Chunk 30581/30626 imported successfully
# Chunk 30582/30626 imported successfully
# Chunk 30583/30626 imported successfully
# Chunk 30584/30626 imported successfully
# Chunk 30585/30626 imported successfully
# Chunk 30586/30626 imported successfully
# Chunk 30587/30626 imported successfully
# Chunk 30588/30626 imported successfully
# Chunk 30589/30626 imported successfully
# Chunk 30590/30626 imported successfully
# Chunk 30591/30626 imported successfully
# Chunk 30592/30626 imported successfully
# Chunk 30593/30626 imported successfully
# Chunk 30594/30626 imported successfully
# Chunk 30595/30626 imported successfully
# Chunk 30596/30626 imported successfully
# Chunk 30597/30626 imported successfully
# Chunk 30598/30626 imported successfully
# Chunk 30599/30626 imported successfully
# Chunk 30600/30626 imported successfully
# Chunk 30601/30626 imported successfully
# Chunk 30602/30626 imported successfully
# Chunk 30603/30626 imported successfully
# Chunk 30604/30626 imported successfully
# Chunk 30605/30626 imported successfully
# Chunk 30606/30626 imported successfully
# Chunk 30607/30626 imported successfully
# Chunk 30608/30626 imported successfully
# Chunk 30609/30626 imported successfully
# Chunk 30610/30626 imported successfully
# Chunk 30611/30626 imported successfully
# Chunk 30612/30626 imported successfully
# Chunk 30613/30626 imported successfully
# Chunk 30614/30626 imported successfully
# Chunk 30615/30626 imported successfully
# Chunk 30616/30626 imported successfully
# Chunk 30617/30626 imported successfully
# Chunk 30618/30626 imported successfully
# Chunk 30619/30626 imported successfully
# Chunk 30620/30626 imported successfully
# Chunk 30621/30626 imported successfully
# Chunk 30622/30626 imported successfully
# Chunk 30623/30626 imported successfully
# Chunk 30624/30626 imported successfully
# Chunk 30625/30626 imported successfully
# Chunk 30626/30626 imported successfully

# %%
import pandas as pd
from collections import defaultdict
import ast  # For safely evaluating stringified lists

# Step 1: Load Movie and Ratings Data
movies_df = pd.read_csv('enriched_impactful_movies.csv')  # Assuming movie data is in a CSV
ratings_df = pd.read_csv('filtered_ratings_top_movies.csv')  # Assuming ratings data is in a CSV

# Step 2: Preprocess movie data to split genres and convert stringified lists
def preprocess_movie_data(row):
    # Split genres by '|'
    row['genres'] = row['genres'].split('|') if isinstance(row['genres'], str) else []
    
    # Convert stringified lists for director and actors to actual lists
    row['director'] = ast.literal_eval(row['director']) if isinstance(row['director'], str) else []
    row['actors'] = ast.literal_eval(row['actors']) if isinstance(row['actors'], str) else []
    
    # Convert stringified tmdb_genres to actual lists
    row['tmdb_genres'] = ast.literal_eval(row['tmdb_genres']) if isinstance(row['tmdb_genres'], str) else []
    
    return row

# Apply preprocessing to the DataFrame
movies_df = movies_df.apply(preprocess_movie_data, axis=1)

# Create a mapping for quick access
movies_mapping = movies_df.set_index("movieId").to_dict(orient="index")

# Step 3: Initialize user profiles
MIN_RATING = 3
user_profiles = defaultdict(lambda: {"directors": defaultdict(int), "actors": defaultdict(int), "genres": defaultdict(int)})

# Step 4: Process the ratings data to aggregate directors, actors, and genres
for _, row in ratings_df.iterrows():
    user_id = row['userId']
    movie_id = row['movieId']
    rating = row['rating']

    # Apply the rating filter
    if rating >= MIN_RATING:
        # Fetch the corresponding movie details from the movies_mapping
        movie = movies_mapping.get(movie_id, None)
        if not movie:
            continue  # Skip if movie details are not found
        
        # Aggregate directors
        for director in movie.get("director", []):  # Use 'director' as per the movie data
            user_profiles[user_id]["directors"][director] += 1
        
        # Aggregate actors
        for actor in movie.get("actors", []):  # Use 'actors' as per the movie data
            user_profiles[user_id]["actors"][actor] += 1
        
        # Aggregate Genres
        for genre in movie.get("genres", []):  # Use processed genres
            user_profiles[user_id]["genres"][genre] += 1

# %%
print(user_profiles[ratings_df.iloc[0]["userId"]])
# Out:
# {'directors': defaultdict(<class 'int'>, {'Ang Lee': 2, 'Zhang Yimou': 1, 'Terry Gilliam': 1, 'Jafar Panahi': 1, 'Mel Gibson': 1, 'Martin Scorsese': 3, 'Gregg Araki': 1, 'Tom DiCillo': 1, 'Kevin Smith': 1, 'George Lucas': 1, 'Patrice Chéreau': 1, 'Krzysztof Kieślowski': 2, 'George Huang': 1, 'Steven Spielberg': 3, 'Ridley Scott': 1, 'Todd Solondz': 1, 'Jonathan Demme': 2, 'Claude Sautet': 1, 'John Sayles': 1, 'Annette Haywood-Carter': 1, 'Douglas McGrath': 1, 'Alfred Hitchcock': 2, 'Billy Wilder': 2, 'William Wyler': 2, 'Orson Welles': 1, 'Joseph L. Mankiewicz': 1, 'George Cukor': 1, 'Richard Brooks': 1, 'Mike Leigh': 1, 'Michael Winterbottom': 1, 'Oliver Stone': 1, 'Neil Jordan': 1, 'Daniel Vigne': 1, 'Giuseppe Tornatore': 1, 'Stanley Kubrick': 1, 'Anthony Minghella': 1, 'Irvin Kershner': 1, 'James Cameron': 2, 'Sidney Lumet': 1, 'Francis Ford Coppola': 2, 'Akira Kurosawa': 2, 'Miloš Forman': 1, 'Wolfgang Petersen': 1, 'George Roy Hill': 2, 'Hal Hartley': 1, 'Mike Nichols': 2, 'Rob Reiner': 2, 'John Sturges': 1, 'Michael Cimino': 1, 'Robert Zemeckis': 1, 'Franklin J. Schaffner': 2, 'Stuart Rosenberg': 1, 'James Ivory': 1, 'Martha Coolidge': 1, 'Alexander Payne': 2, 'Andrew Niccol': 1, 'Atom Egoyan': 1, 'Alex Proyas': 1, 'Don Roos': 1, 'John Schlesinger': 1, 'Alex Cox': 1, 'John Hughes': 2, 'Stephen Frears': 1, 'Adrian Lyne': 1, 'Michael Moore': 1, 'Andy Tennant': 1, 'Vincenzo Natali': 1, 'David Lynch': 1, 'Tony Kaye': 1, 'Shekhar Kapur': 1, 'Lawrence Kasdan': 1, 'John Madden': 1, 'Mike Judge': 1, 'George Seaton': 1, 'Richard Donner': 1, 'Oliver Parker': 1, 'Penny Marshall': 1, 'David O. Russell': 1, 'Robert Aldrich': 1, 'Woody Allen': 1, 'Paul Verhoeven': 1, 'Spike Jonze': 1, 'Henry Koster': 1}), 'actors': defaultdict(<class 'int'>, {'Emma Thompson': 2, 'Kate Winslet': 3, 'Alan Rickman': 1, 'Hugh Grant': 1, 'Gemma Jones': 1, 'Gong Li': 1, 'Li Baotian': 1, 'Sun Chun': 1, 'Li Xuejian': 1, 'Liu Jiang': 1, 'Bruce Willis': 1, 'Madeleine Stowe': 1, 'Brad Pitt': 1, 'Christopher Plummer': 1, 'David Morse': 1, 'Aida Mohammadkhani': 1, 'Mohsen Kafili': 1, 'Fereshteh Sadr Orafaee': 1, 'Anna Borkowska': 1, 'Mohammad Shahani': 1, 'Mel Gibson': 1, 'Catherine McCormack': 1, 'Sophie Marceau': 1, 'Patrick McGoohan': 1, 'Angus Macfadyen': 1, 'Robert De Niro': 5, 'Jodie Foster': 2, 'Cybill Shepherd': 1, 'Harvey Keitel': 1, 'Peter Boyle': 1, 'Rose McGowan': 1, 'James Duval': 1, 'Johnathon Schaech': 1, 'Cress Williams': 1, 'Dustin Nguyen': 1, 'Steve Buscemi': 1, 'Catherine Keener': 2, 'Dermot Mulroney': 1, 'Danielle von Zerneck': 1, 'James Le Gros': 1, "Brian O'Halloran": 1, 'Jeff Anderson': 1, 'Marilyn Ghigliotti': 1, 'Lisa Spoonauer': 1, 'Jason Mewes': 1, 'Lung Sihung': 1, 'Yang Kuei-Mei': 1, 'Wu Chien-Lien': 1, 'Wang Yu-wen': 1, 'Winston Chao': 1, 'Mark Hamill': 2, 'Harrison Ford': 3, 'Carrie Fisher': 2, 'Peter Cushing': 1, 'Alec Guinness': 1, 'Isabelle Adjani': 1, 'Daniel Auteuil': 1, 'Jean-Hugues Anglade': 1, 'Vincent Perez': 1, 'Virna Lisi': 1, 'Irène Jacob': 1, 'Jean-Louis Trintignant': 1, 'Frédérique Feder': 1, 'Jean-Pierre Lorit': 1, 'Samuel Le Bihan': 1, 'Juliette Binoche': 2, 'Benoît Régent': 1, 'Florence Pernel': 1, 'Charlotte Véry': 1, 'Hélène Vincent': 1, 'Kevin Spacey': 1, 'Frank Whaley': 1, 'Michelle Forbes': 1, 'Benicio del Toro': 1, 'T.E. Russell': 1, 'Liam Neeson': 1, 'Ben Kingsley': 1, 'Ralph Fiennes': 2, 'Caroline Goodall': 1, 'Jonathan Sagall': 1, 'Rutger Hauer': 1, 'Sean Young': 1, 'Edward James Olmos': 1, 'M. Emmet Walsh': 1, 'Heather Matarazzo': 1, 'Matthew Faber': 1, 'Daria Kalinina': 1, 'Brendan Sexton III': 1, 'Eric Mabius': 1, 'Anthony Hopkins': 3, 'Scott Glenn': 1, 'Ted Levine': 1, 'Anthony Heald': 1, 'Emmanuelle Béart': 1, 'Michel Serrault': 1, 'Claire Nadeau': 1, 'Françoise Brion': 1, 'Michael Lonsdale': 1, 'Chris Cooper': 1, 'Matthew McConaughey': 2, 'Elizabeth Peña': 1, 'Kris Kristofferson': 1, 'Joe Morton': 1, 'Hedy Burress': 1, 'Angelina Jolie': 1, 'Jenny Lewis': 1, 'Jenny Shimizu': 1, 'Sarah Rosenberg': 1, 'Gw ...

# %%
# Check if 'users' collection exists, create if not
if not db.has_collection('users'):
    db.create_collection('users')

users_collection = db.collection('users')
bulk_insert_data = []

for user_id, data in user_profiles.items():
    bulk_insert_data.append({
        "_key": str(user_id),
        "favorite_genres": sorted(data["genres"], key=data["genres"].get, reverse=True)[:5],
        "frequently_rated_directors": sorted(data["directors"], key=data["directors"].get, reverse=True)[:5],
        "frequently_rated_actors": sorted(data["actors"], key=data["actors"].get, reverse=True)[:5]
    })

chunk_size = 1000
print("Inserting user profiles into the database...")

for i in range(0, len(bulk_insert_data), chunk_size):
    try:
        # Use import_bulk or insert_many based on your ArangoDB driver support
        users_collection.import_bulk(bulk_insert_data[i:i+chunk_size])
        print(f"Inserted {i + len(bulk_insert_data[i:i+chunk_size])} profiles...")
    except Exception as e:
        print(f"Error inserting data at chunk starting index {i}: {str(e)}")

print(f"User profiles created and stored in the 'users' collection.")
# Out:
# Inserting user profiles into the database...
# Inserted 1000 profiles...
# Inserted 2000 profiles...
# Inserted 3000 profiles...
# Inserted 4000 profiles...
# Inserted 5000 profiles...
# Inserted 6000 profiles...
# Inserted 7000 profiles...
# Inserted 8000 profiles...
# Inserted 9000 profiles...
# Inserted 10000 profiles...
# Inserted 11000 profiles...
# Inserted 12000 profiles...
# Inserted 13000 profiles...
# Inserted 14000 profiles...
# Inserted 15000 profiles...
# Inserted 16000 profiles...
# Inserted 17000 profiles...
# Inserted 18000 profiles...
# Inserted 19000 profiles...
# Inserted 20000 profiles...
# Inserted 21000 profiles...
# Inserted 22000 profiles...
# Inserted 23000 profiles...
# Inserted 24000 profiles...
# Inserted 25000 profiles...
# Inserted 26000 profiles...
# Inserted 27000 profiles...
# Inserted 28000 profiles...
# Inserted 29000 profiles...
# Inserted 30000 profiles...
# Inserted 31000 profiles...
# Inserted 32000 profiles...
# Inserted 33000 profiles...
# Inserted 34000 profiles...
# Inserted 35000 profiles...
# Inserted 36000 profiles...
# Inserted 37000 profiles...
# Inserted 38000 profiles...
# Inserted 39000 profiles...
# Inserted 40000 profiles...
# Inserted 41000 profiles...
# Inserted 42000 profiles...
# Inserted 43000 profiles...
# Inserted 44000 profiles...
# Inserted 45000 profiles...
# Inserted 46000 profiles...
# Inserted 47000 profiles...
# Inserted 48000 profiles...
# Inserted 49000 profiles...
# Inserted 50000 profiles...
# Inserted 51000 profiles...
# Inserted 52000 profiles...
# Inserted 53000 profiles...
# Inserted 54000 profiles...
# Inserted 55000 profiles...
# Inserted 56000 profiles...
# Inserted 57000 profiles...
# Inserted 58000 profiles...
# Inserted 59000 profiles...
# Inserted 60000 profiles...
# Inserted 61000 profiles...
# Inserted 62000 profiles...
# Inserted 63000 profiles...
# Inserted 64000 profiles...
# Inserted 65000 profiles...
# Inserted 66000 profiles...
# Inserted 67000 profiles...
# Inserted 68000 profiles...
# Inserted 69000 profiles...
# Inserted 70000 profiles...
# Inserted 71000 profiles...
# Inserted 72000 profiles...
# Inserted 73000 profiles...
# Inserted 74000 profiles...
# Inserted 75000 profiles...
# Inserted 76000 profiles...
# Inserted 77000 profiles...
# Inserted 78000 profiles...
# Inserted 79000 profiles...
# Inserted 80000 profiles...
# Inserted 81000 profiles...
# Inserted 82000 profiles...
# Inserted 83000 profiles...
# Inserted 84000 profiles...
# Inserted 85000 profiles...
# Inserted 86000 profiles...
# Inserted 87000 profiles...
# Inserted 88000 profiles...
# Inserted 89000 profiles...
# Inserted 90000 profiles...
# Inserted 91000 profiles...
# Inserted 92000 profiles...
# Inserted 93000 profiles...
# Inserted 94000 profiles...
# Inserted 95000 profiles...
# Inserted 96000 profiles...
# Inserted 97000 profiles...
# Inserted 98000 profiles...
# Inserted 99000 profiles...
# Inserted 100000 profiles...
# Inserted 101000 profiles...
# Inserted 102000 profiles...
# Inserted 103000 profiles...
# Inserted 104000 profiles...
# Inserted 105000 profiles...
# Inserted 106000 profiles...
# Inserted 107000 profiles...
# Inserted 108000 profiles...
# Inserted 109000 profiles...
# Inserted 110000 profiles...
# Inserted 111000 profiles...
# Inserted 112000 profiles...
# Inserted 113000 profiles...
# Inserted 114000 profiles...
# Inserted 115000 profiles...
# Inserted 116000 profiles...
# Inserted 117000 profiles...
# Inserted 118000 profiles...
# Inserted 119000 profiles...
# Inserted 120000 profiles...
# Inserted 121000 profiles...
# Inserted 122000 profiles...
# Inserted 123000 profiles...
# Inserted 124000 profiles...
# Inserted 125000 profiles...
# Inserted 126000 profiles...
# Inserted 127000 profiles...
# Inserted 128000 profiles...
# Inserted 129000 profiles...
# Inserted 130000 profiles...
# Inserted 131000 profiles...
# Inserted 132000 profiles...
# Inserted 133000 profiles...
# Inserted 134000 profiles...
# Inserted 135000 profiles...
# Inserted 136000 profiles...
# Inserted 137000 profiles...
# Inserted 138000 profiles...
# Inserted 139000 profiles...
# Inserted 140000 profiles...
# Inserted 141000 profiles...
# Inserted 142000 profiles...
# Inserted 143000 profiles...
# Inserted 144000 profiles...
# Inserted 145000 profiles...
# Inserted 146000 profiles...
# Inserted 147000 profiles...
# Inserted 148000 profiles...
# Inserted 149000 profiles...
# Inserted 150000 profiles...
# Inserted 151000 profiles...
# Inserted 152000 profiles...
# Inserted 153000 profiles...
# Inserted 154000 profiles...
# Inserted 155000 profiles...
# Inserted 156000 profiles...
# Inserted 157000 profiles...
# Inserted 158000 profiles...
# Inserted 159000 profiles...
# Inserted 160000 profiles...
# Inserted 161000 profiles...
# Inserted 162000 profiles...
# Inserted 163000 profiles...
# Inserted 164000 profiles...
# Inserted 165000 profiles...
# Inserted 166000 profiles...
# Inserted 167000 profiles...
# Inserted 168000 profiles...
# Inserted 169000 profiles...
# Inserted 170000 profiles...
# Inserted 171000 profiles...
# Inserted 172000 profiles...
# Inserted 173000 profiles...
# Inserted 174000 profiles...
# Inserted 175000 profiles...
# Inserted 176000 profiles...
# Inserted 177000 profiles...
# Inserted 178000 profiles...
# Inserted 179000 profiles...
# Inserted 180000 profiles...
# Inserted 181000 profiles...
# Inserted 182000 profiles...
# Inserted 183000 profiles...
# Inserted 184000 profiles...
# Inserted 185000 profiles...
# Inserted 186000 profiles...
# Inserted 187000 profiles...
# Inserted 188000 profiles...
# Inserted 189000 profiles...
# Inserted 190000 profiles...
# Inserted 191000 profiles...
# Inserted 192000 profiles...
# Inserted 193000 profiles...
# Inserted 194000 profiles...
# Inserted 195000 profiles...
# Inserted 196000 profiles...
# Inserted 197000 profiles...
# Inserted 198000 profiles...
# Inserted 199000 profiles...
# Inserted 200000 profiles...
# Inserted 200891 profiles...
# User profiles created and stored in the 'users' collection.

# %%
import pandas as pd
from collections import defaultdict

# Step 1: Connect to ArangoDB
from arango import ArangoClient

client = ArangoClient()
db = client.db('movieRecommendations', username='root', password='rootPassword')

users_collection = db.collection('users')
movies_collection = db.collection('movies')

# Step 2: Fetch User Profile
def get_user_profile(user_id):
    formatted_user_id = f"{float(user_id):.1f}"
    
    
    user_profile = users_collection.get(formatted_user_id)
    if not user_profile:
        print(f"User {user_id} not found in the database.")
        return None
    return user_profile

# Step 3: Find Matching Movies
def recommend_movies(user_id, top_n=10):
    user_profile = get_user_profile(user_id)
    if not user_profile:
        return []

    favorite_genres = set(user_profile.get('favorite_genres', []))
    favorite_directors = set(user_profile.get('frequently_rated_directors', []))
    favorite_actors = set(user_profile.get('frequently_rated_actors', []))

    # Query all movies
    movies_cursor = movies_collection.all()
    recommendations = []

    for movie in movies_cursor:
        score = 0

        # Genre matching
        movie_genres = set(movie.get('genres', []))
        genre_matches = len(favorite_genres & movie_genres)
        score += genre_matches * 2  # Weight for genre matches

        # Director matching
        movie_directors = set(movie.get('directors', []))
        director_matches = len(favorite_directors & movie_directors)
        score += director_matches * 3  # Weight for director matches

        # Actor matching
        movie_actors = set(movie.get('actors', []))
        actor_matches = len(favorite_actors & movie_actors)
        score += actor_matches * 1  # Weight for actor matches

        # Add to recommendations if score > 0
        if score > 0:
            recommendations.append({
                "movieId": movie["_key"],
                "title": movie["title"],
                "genres": movie.get("genres", []),
                "directors": movie.get("directors", []),
                "actors": movie.get("actors", []),
                "score": score
            })

    # Sort by score in descending order
    recommendations = sorted(recommendations, key=lambda x: x['score'], reverse=True)

    return recommendations[:top_n]

# Step 4: Test the Script
if __name__ == "__main__":
    test_user_id = "1000"  
    top_recommendations = recommend_movies(test_user_id, top_n=10)

    if top_recommendations:
        print(f"Top {len(top_recommendations)} recommendations for User {test_user_id}:")
        for idx, movie in enumerate(top_recommendations, start=1):
            print(f"{idx}. {movie['title']} (Score: {movie['score']})")
            print(f"   Genres: {', '.join(movie['genres'])}")
            print(f"   Directors: {', '.join(movie['directors'])}")
            print(f"   Actors: {', '.join(movie['actors'])}")
    else:
        print(f"No recommendations available for User {test_user_id}.")
# Out:
# Top 10 recommendations for User 1000:
# 1. Stunt Man, The (1980) (Score: 10)
#    Genres: Action, Adventure, Comedy, Drama, Romance, Thriller
#    Directors:
#    Actors: "Peter OToole", Steve Railsback, Barbara Hershey, Allen Garfield, Alex Rocco
# 2. National Treasure (2004) (Score: 10)
#    Genres: Action, Adventure, Drama, Mystery, Thriller
#    Directors:
#    Actors: Nicolas Cage, Diane Kruger, Justin Bartha, Sean Bean, Jon Voight
# 3. Hunting Party, The (2007) (Score: 10)
#    Genres: Action, Adventure, Comedy, Drama, Thriller
#    Directors:
#    Actors: Richard Gere, Terrence Howard, Jesse Eisenberg, James Brolin, Diane Kruger
# 4. Rubber (2010) (Score: 10)
#    Genres: Action, Adventure, Comedy, Crime, Drama, Film-Noir, Horror, Mystery, Thriller, Western
#    Directors:
#    Actors: Thomas F. Duffy, David Bowe, Stephen Spinella, Roxane Mesquida, Jack Plotnick
# 5. Getaway, The (1994) (Score: 9)
#    Genres: Action, Adventure, Crime, Drama, Romance, Thriller
#    Directors:
#    Actors: Alec Baldwin, Kim Basinger, Michael Madsen, James Woods, David Morse
# 6. Runaway Train (1985) (Score: 9)
#    Genres: Action, Adventure, Drama, Thriller
#    Directors:
#    Actors: Jon Voight, Eric Roberts, Rebecca De Mornay, Kyle T. Heffner, John P. Ryan
# 7. Machete (2010) (Score: 9)
#    Genres: Action, Adventure, Comedy, Crime, Thriller
#    Directors:
#    Actors: Danny Trejo, Michelle Rodriguez, Jessica Alba, Robert De Niro, Steven Seagal
# 8. Money Train (1995) (Score: 8)
#    Genres: Action, Comedy, Crime, Drama, Thriller
#    Directors:
#    Actors: Wesley Snipes, Woody Harrelson, Jennifer Lopez, Robert Blake, Chris Cooper
# 9. Bad Boys (1995) (Score: 8)
#    Genres: Action, Comedy, Crime, Drama, Thriller
#    Directors:
#    Actors: Will Smith, Martin Lawrence, Téa Leoni, Tchéky Karyo, Joe Pantoliano
# 10. True Lies (1994) (Score: 8)
#    Genres: Action, Adventure, Comedy, Romance, Thriller
#    Directors:
#    Actors: Arnold Schwarzenegger, Jamie Lee Curtis, Tom Arnold, Bill Paxton, Tia Carrere
